# %% [markdown]
# # Import

# %%
from sqlalchemy import create_engine
import pymysql
import pandas as pd

# %%
db_connection_str = 'mysql+pymysql://soongle:wlghwlgn12@esportsmanager.cx6nzwirrgvm.ap-northeast-2.rds.amazonaws.com/EsportsManager'
db_connection = create_engine(db_connection_str)
conn = db_connection.connect()

# %%
df=pd.read_csv("./csv/base_team.csv",sep=";",encoding="utf-8")

# %%
df=df[['id','logo','name']]
df
# Out:
#    id                                               logo                 name
# 0   1  https://lck-esports-manager.s3.ap-northeast-2....                   T1
# 1   2  https://lck-esports-manager.s3.ap-northeast-2....                Gen.G
# 2   3  https://lck-esports-manager.s3.ap-northeast-2....                  DRX
# 3   4  https://lck-esports-manager.s3.ap-northeast-2....              DWG KIA
# 4   5  https://lck-esports-manager.s3.ap-northeast-2....         Fredit BRION
# 5   6  https://lck-esports-manager.s3.ap-northeast-2....     Kwangdong Freecs
# 6   7  https://lck-esports-manager.s3.ap-northeast-2....  Hanwha Life Esports
# 7   8  https://lck-esports-manager.s3.ap-northeast-2....           KT Rolster
# 8   9  https://lck-esports-manager.s3.ap-northeast-2....         Liiv SANDBOX
# 9  10  https://lck-esports-manager.s3.ap-northeast-2....    Nongshim RedForce

# %%
df.to_sql(name='base_team', con=db_connection, if_exists='append',index=False)
# Out:
# 10

# %%
df2=pd.read_csv("./csv/player_final.csv",sep=";",encoding="utf-8")
df2=df2[['id','nick_name','real_name','position','lane_status','fight_status','operation_status','roaming_status',
'ganking_status','jungling_status','grade','image','base_team_id']]
df2
# Out:
#     id   nick_name real_name position  lane_status  fight_status  \
# 0    1       Canna       김창동      TOP           80            60
# 1    2       Doran       최현준      TOP           70            90
# 2    3        Dove       김재연      TOP           50            70
# 3    4        DuDu       이동주      TOP           70            50
# 4    5        Kiin       김기인      TOP           60            50
# 5    6      Kingen       황성훈      TOP           50            70
# 6    7      Morgan       박기태      TOP           60            50
# 7    8      Nuguri       장하권      TOP           70            70
# 8    9      Rascal       김광희      TOP           70            60
# 9   10       Sw0rd       최성원      TOP           50            50
# 10  11        Zeus       최우제      TOP           80            80
# 11  12      Canyon       김건부   JUNGLE           30            90
# 12  13       Croco       김동범   JUNGLE           30            80
# ...

# %%
df2.to_sql(name='player', con=db_connection, if_exists='append',index=False)
# Out:
# 58

# %%
df2=pd.read_csv("./csv/player_final.csv",sep=";",encoding="utf-8")
df2=df2[['id','nick_name','real_name','position','lane_status','fight_status','operation_status','roaming_status',
'ganking_status','jungling_status','grade','image','base_team_id']]
df2

# %%
df3=pd.read_csv("./csv/champion_final.csv",sep=";",encoding="utf-8")
df3=df3[['id','korean_name','english_name','image','lane_status','fight_status','operation_status','roaming_status',
'ganking_status','jungling_status','first','middle','end','position','tier']]

# %%
df3.to_sql(name='champion', con=db_connection, if_exists='append',index=False)
# Out:
# 161

# %%
df4=pd.read_csv("./csv/league_schedule_final.csv",sep=";",encoding="utf-8")
df4=df4[['id','day','team1_id','team2_id','is_game','is_playoff']]

# %%
df4.to_sql(name='league_schedule', con=db_connection, if_exists='append',index=False)
# Out:
# 115

# %%
df5=pd.read_csv("./csv/enterprise.csv",sep=";",encoding="utf-8")
df5=df5[['id','cost','description','earning_money','image','name']]
df5
# Out:
#    id       cost     description  earning_money  \
# 0   1   10000000  유튜브 사업으로 돈을 번다        1000000
# 1   2  100000000   굿즈 사업으로 돈을 번다        5000000
#
#                                                image    name
# 0  https://lck-esports-manager.s3.ap-northeast-2....  유튜브 사업
# 1  https://lck-esports-manager.s3.ap-northeast-2....   굿즈 사업

# %%
df5.to_sql(name='enterprise', con=db_connection, if_exists='append',index=False)
# Out:
# 2

# %%
df6=pd.read_csv("./csv/sponsor.csv",sep=";",encoding="utf-8")
df6=df6[['id','description','image','money','name','win']]
df6
# Out:
#    id      description                                              image  \
# 0   1  유명 컴퓨터 주변기기 브랜드  https://lck-esports-manager.s3.ap-northeast-2....
# 1   2       유명 스포츠 브랜드  https://lck-esports-manager.s3.ap-northeast-2....
# 2   3       대한민국 최고 기업  https://lck-esports-manager.s3.ap-northeast-2....
#
#      money  name  win
# 0  1000000   로지텍    5
# 1  2000000  아디다스    8
# 2  4000000    삼성   12

# %%
df6.to_sql(name='sponsor', con=db_connection, if_exists='append',index=False)
# Out:
# 3

# %%
df7=pd.read_csv("./csv/personal_schedule.csv",sep=";",encoding="utf-8")
df7=df7[['id','description','exp','money','name','status']]
df7
# Out:
#    id                  description  exp   money name  status
# 0   1  컨디션이 약간 상승하고 경험치가 약간 상승합니다.   10       0   운동       1
# 1   2                 컨디션이 최상이 됩니다    0       0   명상       2
# 2   3  컨디션이 소폭 하락하지만 추가적인 자본을 얻습니다    0  100000   방송      -1
# 3   4   컨디션이 최악이 되지만 경험치가 대량 상승합니다   30       0   연습      -2

# %%
df7.to_sql(name='personal_schedule', con=db_connection, if_exists='append',index=False)
# Out:
# 4

# %%
conn.close()

# %% [markdown]
# ## Get html
