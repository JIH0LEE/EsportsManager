# %% [markdown]
# # Import

# %%
import pandas as pd;

# %%
df=pd.read_csv("./csv/player.csv", encoding="utf-8-sig",sep=";")

# %% [markdown]
# ## Add Tier

# %%
df.head()
# Out:
#   nick_name  base_team_id position  lane_status  operation_status  \
# 0     Canna            10      Top           80                60
# 1     Doran             2      Top           70                90
# 2      Dove             9      Top           50                80
# 3      DuDu             7      Top           70                50
# 4      Kiin             6      Top           60                60
#
#    fight_status grade  id real_name  \
# 0            60     R   1       김창동
# 1            90    UR   2       최현준
# 2            70     R   3       김재연
# 3            50     C   4       이동주
# 4            50     C   5       김기인
#
#                                                image
# 0  https://lck-esports-manager.s3.ap-northeast-2....
# 1  https://lck-esports-manager.s3.ap-northeast-2....
# 2  https://lck-esports-manager.s3.ap-northeast-2....
# 3  https://lck-esports-manager.s3.ap-northeast-2....
# 4  https://lck-esports-manager.s3.ap-northeast-2....

# %%
df['roaming_status']=0
df['ganking_status']=0
df['jungling_status']=0

# %%
df.head()
# Out:
#   nick_name  base_team_id position  lane_status  operation_status  \
# 0     Canna            10      Top           80                60
# 1     Doran             2      Top           70                90
# 2      Dove             9      Top           50                80
# 3      DuDu             7      Top           70                50
# 4      Kiin             6      Top           60                60
#
#    fight_status grade  id real_name  \
# 0            60     R   1       김창동
# 1            90    UR   2       최현준
# 2            70     R   3       김재연
# 3            50     C   4       이동주
# 4            50     C   5       김기인
#
#                                                image  roaming_status  \
# 0  https://lck-esports-manager.s3.ap-northeast-2....               0
# 1  https://lck-esports-manager.s3.ap-northeast-2....               0
# 2  https://lck-esports-manager.s3.ap-northeast-2....               0
# ...

# %%
df.to_csv("./csv/player_status.csv",index=False,sep=";",encoding="utf-8-sig")
