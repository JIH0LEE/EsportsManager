# %% [markdown]
# # Import

# %%
import pandas as pd

# %%
df = pd.read_csv("./csv/player_no_image.csv",sep=";",encoding="utf-8")

# %%
df
# Out:
#      nick_name  base_team_id position  lane_status  operation_status  \
# 0        Canna          10.0      Top         80.0              60.0
# 1        Doran           2.0      Top         70.0              90.0
# 2         Dove           9.0      Top         50.0              80.0
# 3         DuDu           7.0      Top         70.0              50.0
# 4         Kiin           6.0      Top         60.0              60.0
# ..         ...           ...      ...          ...               ...
# 57        Life           8.0  Support         60.0              70.0
# 58       Moham           6.0  Support         80.0              50.0
# 59       Peter          10.0  Support         50.0              50.0
# 60  SnowFlower          10.0  Support         70.0              60.0
# 61        Vsta           7.0  Support         50.0              50.0
#
#     fight_status grade    id real_name
# 0           60.0     R   1.0       김창동
# 1           90.0    UR   2.0       최현준
# 2           70.0     R   3.0       김재연
# 3           50.0     C   4.0       이동주
# 4           50.0     C   5.0       김기인
# ..           ...   ...   ...       ...
# 57          70.0     N  58.0       김정민
# 58          50.0     N  59.0       정재훈
# 59          50.0     C  60.0       정윤수
# 60          60.0     N  61.0       노회종
# 61          50.0     C  62.0       오효성
#
# [62 rows x 9 columns]

# %%
df.dropna()
# Out:
#      nick_name  base_team_id position  lane_status  operation_status  \
# 0        Canna          10.0      Top         80.0              60.0
# 1        Doran           2.0      Top         70.0              90.0
# 2         Dove           9.0      Top         50.0              80.0
# 3         DuDu           7.0      Top         70.0              50.0
# 4         Kiin           6.0      Top         60.0              60.0
# 5       Kingen           3.0      Top         50.0              70.0
# 6       Morgan           5.0      Top         60.0              70.0
# 7       Nuguri           4.0      Top         70.0              60.0
# 8       Rascal           8.0      Top         70.0              60.0
# 9        Sw0rd           5.0      Top         50.0              50.0
# 10        Zeus           1.0      Top         80.0              60.0
# 11      Canyon           4.0   Jungle         60.0              80.0
# 12       Croco           9.0   Jungle         60.0              60.0
# 13        Cuzz           8.0   Jungle         70.0              60.0
# 14       Dread          10.0   Jungle         60.0              60.0
# 15       Ellim           6.0   Jungle         50.0              70.0
# 16       Juhan           3.0   Jungle         50.0              70.0
# 17        Oner           1.0   Jungle         90.0              70.0
# 18     OnFleek           7.0   Jungle         50.0              50.0
# 19      Peanut           2.0   Jungle         90.0              90.0
# 20      Pyosik           3.0   Jungle         80.0              80.0
# 23        UmTi           5.0   Jungle         50.0              60.0
# 24      Willer           7.0   Jungle         60.0              50.0
# 25        Aria           8.0   Middle         50.0              90.0
# 26         Bdd          10.0   Middle         60.0              60.0
# 27       Chovy           2.0   Middle         90.0              80.0
# 28      Clozer           9.0   Middle         70.0              60.0
# 29       Faker           1.0   Middle         70.0              70.0
# 30        FATE           6.0   Middle         60.0              50.0
# 31       Karis           7.0   Middle         50.0              50.0
# 32        Lava           5.0   Middle         50.0              50.0
# 33   ShowMaker           4.0   Middle         70.0              70.0
# 34       VicLa           8.0   Middle         70.0              80.0
# 35        Zeka           3.0   Middle         70.0              60.0
# 36      Aiming           8.0      ADC         70.0              70.0
# 37      Cheoni           7.0      ADC         50.0              50.0
# 38        Deft           3.0      ADC         60.0              70.0
# 39     deokdam           4.0      ADC         60.0              60.0
# 41       Ghost          10.0      ADC         50.0              60.0
# 42    Gumayusi           1.0      ADC         70.0              70.0
# 43        Hena           5.0      ADC         70.0              50.0
# 44      Prince           9.0      ADC         90.0              70.0
# 45       Ruler           2.0      ADC         70.0              90.0
# 46        SamD           7.0      ADC         60.0              50.0
# 47       Teddy           6.0      ADC         50.0              70.0
# 48       BeryL           3.0  Support         90.0              60.0
# 50     Delight           5.0  Support         50.0              60.0
# 51      Effort          10.0  Support         70.0              60.0
# 52        Hoit           6.0  Support         90.0              60.0
# 53        Kael           9.0  Support         50.0              90.0
# 54      Kellin           4.0  Support         50.0              90.0
# 55       Keria           1.0  Support         70.0              80.0
# 56     Lehends           2.0  Support         70.0              80.0
# 57        Life           8.0  Support         60.0              70.0
# 58       Moham           6.0  Support         80.0              50.0
# 59       Peter          10.0  Support         50.0              50.0
# 60  SnowFlower          10.0  Support         70.0              60.0
# 61        Vsta           7.0  Support         50.0              50.0
#
#     fight_status grade    id real_name
# 0           60.0     R   1.0       김창동
# 1           90.0    UR   2.0       최현준
# 2           70.0     R   3.0       김재연
# 3           50.0     C   4.0       이동주
# 4           50.0     C   5.0       김기인
# 5           70.0     N   6.0       황성훈
# 6           50.0     N   7.0       박기태
# 7           70.0     R   8.0       장하권
# 8           60.0     N   9.0       김광희
# 9           50.0     C  10.0       최성원
# 10          80.0    SR  11.0       최우제
# 11          90.0    SR  12.0       김건부
# 12          80.0     N  13.0       김동범
# 13          70.0     N  14.0       문우찬
# 14          70.0     N  15.0       이진혁
# 15          50.0     C  16.0       최엘림
# 16          50.0     C  17.0       이주한
# 17          80.0    UR  18.0       문현준
# 18          60.0     C  19.0       김장겸
# 19          90.0    UR  20.0       한왕호
# 20          70.0    SR  21.0       홍창현
# 23          60.0     C  24.0       엄성현
# 24          50.0     C  25.0       김정현
# 25          60.0     N  26.0       이가을
# 26          60.0     N  27.0       곽보성
# 27          90.0    UR  28.0       정지훈
# 28          80.0     R  29.0       이주현
# 29          60.0     N  30.0       이상혁
# 30          50.0     C  31.0       유수혁
# 31          50.0     C  32.0       김홍조
# 32          50.0     C  33.0       김태훈
# 33          70.0     R  34.0        허수
# 34          60.0     R  35.0       이대광
# 35          70.0     N  36.0       김건우
# 36          80.0    SR  37.0       김하람
# 37          50.0     C  38.0       조승모
# 38          60.0     N  39.0       김혁규
# 39          70.0     N  40.0       서대길
# 41          60.0     C  42.0       장용준
# 42          60.0     R  43.0       이민형
# 43          60.0     N  44.0       박증환
# 44          80.0    UR  45.0       이채환
# 45          90.0    UR  46.0       박재혁
# 46          50.0     C  47.0       이재훈
# 47          60.0     N  48.0       박진성
# 48          60.0     R  49.0       조건희
# 50          50.0     C  51.0       유환중
# 51          50.0     N  52.0       이상호
# 52          60.0     R  53.0       류호성
# 53          70.0     R  54.0       김진홍
# 54          90.0    SR  55.0       김형규
# 55          80.0    SR  56.0       류민석
# 56          90.0    UR  57.0       손시우
# 57          70.0     N  58.0       김정민
# 58          50.0     N  59.0       정재훈
# 59          50.0     C  60.0       정윤수
# 60          60.0     N  61.0       노회종
# 61          50.0     C  62.0       오효성

# %%
for idx, item in df.iterrows():
    df.loc[idx,"id"]=idx+1

# %%
df
# Out:
#      nick_name  base_team_id position  lane_status  operation_status  \
# 0        Canna          10.0      Top         80.0              60.0
# 1        Doran           2.0      Top         70.0              90.0
# 2         Dove           9.0      Top         50.0              80.0
# 3         DuDu           7.0      Top         70.0              50.0
# 4         Kiin           6.0      Top         60.0              60.0
# ..         ...           ...      ...          ...               ...
# 57        Life           8.0  Support         60.0              70.0
# 58       Moham           6.0  Support         80.0              50.0
# 59       Peter          10.0  Support         50.0              50.0
# 60  SnowFlower          10.0  Support         70.0              60.0
# 61        Vsta           7.0  Support         50.0              50.0
#
#     fight_status grade    id real_name
# 0           60.0     R   1.0       김창동
# 1           90.0    UR   2.0       최현준
# 2           70.0     R   3.0       김재연
# 3           50.0     C   4.0       이동주
# 4           50.0     C   5.0       김기인
# ..           ...   ...   ...       ...
# 57          70.0     N  58.0       김정민
# 58          50.0     N  59.0       정재훈
# 59          50.0     C  60.0       정윤수
# 60          60.0     N  61.0       노회종
# 61          50.0     C  62.0       오효성
#
# [62 rows x 9 columns]

# %%
df['id']=df['id'].astype("int64")
df["image"] = "image"

# %%
url = "https://lck-esports-manager.s3.ap-northeast-2.amazonaws.com/player/"

# %%
for idx, item in df.iterrows():
    name = item['nick_name']
    df.loc[idx,"image"]=url+"name"+".png"

# %%
df
# Out:
#      nick_name  base_team_id position  lane_status  operation_status  \
# 0        Canna          10.0      Top         80.0              60.0
# 1        Doran           2.0      Top         70.0              90.0
# 2         Dove           9.0      Top         50.0              80.0
# 3         DuDu           7.0      Top         70.0              50.0
# 4         Kiin           6.0      Top         60.0              60.0
# ..         ...           ...      ...          ...               ...
# 57        Life           8.0  Support         60.0              70.0
# 58       Moham           6.0  Support         80.0              50.0
# 59       Peter          10.0  Support         50.0              50.0
# 60  SnowFlower          10.0  Support         70.0              60.0
# 61        Vsta           7.0  Support         50.0              50.0
#
#     fight_status grade  id real_name  \
# 0           60.0     R   1       김창동
# 1           90.0    UR   2       최현준
# 2           70.0     R   3       김재연
# 3           50.0     C   4       이동주
# 4           50.0     C   5       김기인
# ..           ...   ...  ..       ...
# 57          70.0     N  58       김정민
# 58          50.0     N  59       정재훈
# 59          50.0     C  60       정윤수
# 60          60.0     N  61       노회종
# 61          50.0     C  62       오효성
#
#                                                 image
# 0   https://lck-esports-manager.s3.ap-northeast-2....
# 1   https://lck-esports-manager.s3.ap-northeast-2....
# 2   https://lck-esports-manager.s3.ap-northeast-2....
# 3   https://lck-esports-manager.s3.ap-northeast-2....
# 4   https://lck-esports-manager.s3.ap-northeast-2....
# ..                                                ...
# 57  https://lck-esports-manager.s3.ap-northeast-2....
# 58  https://lck-esports-manager.s3.ap-northeast-2....
# 59  https://lck-esports-manager.s3.ap-northeast-2....
# 60  https://lck-esports-manager.s3.ap-northeast-2....
# 61  https://lck-esports-manager.s3.ap-northeast-2....
#
# [62 rows x 10 columns]

# %%
df.to_csv("./csv/player.csv",encoding="utf-8-sig",sep=";",index=False)
