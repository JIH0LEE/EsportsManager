# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine

# %%
conn  = pymysql.connect(
    user='soongle', 
    password='wlghwlgn12', 
    database='EsportsManager', 
    host='esportsmanager.cx6nzwirrgvm.ap-northeast-2.rds.amazonaws.com',
    port=3306,
    charset='utf8'
)

# %%
engine = create_engine("mariadb://{user}:{pw}@{host}/{db}".format(user='soongle', pw='wlghwlgn12', host="esportsmanager.cx6nzwirrgvm.ap-northeast-2.rds.amazonaws.com", db='EsportsManager'),encoding="utf8")

# %%
df=pd.read_csv("./csv/player.csv",sep=";",encoding="utf-8")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   nick_name         58 non-null     object
#  1   base_team_id      58 non-null     int64
#  2   position          58 non-null     object
#  3   lane_status       58 non-null     int64
#  4   operation_status  58 non-null     int64
#  5   fight_status      58 non-null     int64
#  6   grade             58 non-null     object
#  7   id                58 non-null     int64
#  8   real_name         58 non-null     object
#  9   image             58 non-null     object
# dtypes: int64(5), object(5)
# memory usage: 4.7+ KB

# %%
df.head(5)
# Out:
#   nick_name  base_team_id position  lane_status  operation_status  \
# 0     Canna            10      TOP           80                60
# 1     Doran             2      TOP           70                90
# 2      Dove             9      TOP           50                80
# 3      DuDu             7      TOP           70                50
# 4      Kiin             6      TOP           60                60
#
#    fight_status grade  id real_name  \
# 0            60     R   1       김창동
# 1            90    UR   2       최현준
# 2            70     R   3       김재연
# 3            50     C   4       이동주
# 4            50     C   5       김기인
#
#                                                image
# 0  https://lck-esports-manager.s3.ap-northeast-2....
# 1  https://lck-esports-manager.s3.ap-northeast-2....
# 2  https://lck-esports-manager.s3.ap-northeast-2....
# 3  https://lck-esports-manager.s3.ap-northeast-2....
# 4  https://lck-esports-manager.s3.ap-northeast-2....

# %%
data = list(df.itertuples(index=False, name=None))

# %%
data
# Out:
# [('Canna',
#   10,
#   'TOP',
#   80,
#   60,
#   60,
#   'R',
#   1,
#   '김창동',
#   'https://lck-esports-manager.s3.ap-northeast-2.amazonaws.com/player/Canna.png'),
#  ('Doran',
#   2,
#   'TOP',
#   70,
#   90,
#   90,
#   'UR',
#   2,
#   '최현준',
#   'https://lck-esports-manager.s3.ap-northeast-2.amazonaws.com/player/Doran.png'),
#  ('Dove',
#   9,
#   'TOP',
#   50,
#   80,
#   70,
#   'R',
#   3,
#   '김재연',
#   'https://lck-esports-manager.s3.ap-northeast-2.amazonaws.com/player/Dove.png'),
#  ('DuDu',
#   7,
#   'TOP',
#   70,
#   50,
#   50,
#   'C',
#   4,
#   '이동주',
#   'https://lck-esports-manager.s3.ap-northeast-2.amazonaws.com/player/DuDu.png'),
#  ('Kiin',
#   6,
#   'TOP',
#   60,
#   60,
#   50,
#   'C',
#   5,
#   '김기인',
#   'https://lck-esports-manager.s3.ap-northeast-2.amazonaws.com/player/Kiin.png'),
#  ('Kingen',
#   3,
#   'TOP',
#   50,
#   70,
#   70,
#   'N',
#   6,
#   '황성훈',
#   'https://lck-esports-manager.s3.ap-northeast-2.amazonaws.com/player/Kingen.png'),
# ...

# %%
sql = """
INSERT INTO champion (
    id,
    nick_name,
    real_name,
    base_team_id,
    position,
    lane_status,
    operation_status,
    fight_status,
    grade,
    image
) VALUES (
    # %s, %s, %s, %s,
    # %s, %s, %s, %s,
    # %s, %s
)
"""

# %%
# cs = conn.cursor()
# cs.executemany(sql, data)
# conn.commit()

# %%
df.to_sql('base_team', engine, if_exists='replace', method="multi", index=False)

# %%
conn.close()
